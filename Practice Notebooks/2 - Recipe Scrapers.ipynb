# %% [markdown]
# ### Import Necessary Packages

# %%
import pandas as pd
import re
import requests
import time
from bs4 import BeautifulSoup
from itertools import chain
from pandas.io.json import json_normalize
from recipe_scrapers import scrape_me
from tqdm import tqdm_notebook as tqdm
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Create Parser Function for Ingredients

# %%
# regex for separating ingredients list
SEPARATOR_RE = re.compile(r'^([\d\s*[\d\.,/]*)\s*(.+)')

# create a normalized string for ingredients
def normalize(st):
    """

    :param st:
    :return:
    """
    return re.sub(r'\s+', ' ', SEPARATOR_RE.sub('\g<1> \g<2>', st)).strip()


def escape_re_string(text):
    """

    :param text:
    :return:
    """
    text = text.replace('.', '\.')
    return re.sub(r'\s+', ' ', text)

# list of common units of measurements for ingredients
UNITS = {"cup": ["cups", "cup", "c.", "c"], "fluid_ounce": ["fl. oz.", "fl oz", "fluid ounce", "fluid ounces"],
         "gallon": ["gal", "gal.", "gallon", "gallons"], "ounce": ["oz", "oz.", "ounce", "ounces"],
         "pint": ["pt", "pt.", "pint", "pints"], "pound": ["lb", "lb.", "pound", "pounds"],
         "quart": ["qt", "qt.", "qts", "qts.", "quart", "quarts"],
         "tablespoon": ["tbsp.", "tbsp", "T", "T.", "tablespoon", "tablespoons", "tbs.", "tbs"],
         "teaspoon": ["tsp.", "tsp", "t", "t.", "teaspoon", "teaspoons"],
         "gram": ["g", "g.", "gr", "gr.", "gram", "grams"], "kilogram": ["kg", "kg.", "kilogram", "kilograms"],
         "liter": ["l", "l.", "liter", "liters"], "milligram": ["mg", "mg.", "milligram", "milligrams"],
         "milliliter": ["ml", "ml.", "milliliter", "milliliters"], "pinch": ["pinch", "pinches"],
         "dash": ["dash", "dashes"], "touch": ["touch", "touches"], "handful": ["handful", "handfuls"],
         "stick": ["stick", "sticks"], "clove": ["cloves", "clove"], "can": ["cans", "can"], "large": ["large"],
         "small": ["small"], "scoop": ["scoop", "scoops"], "filets": ["filet", "filets"], "sprig": ["sprigs", "sprig"]}

# numbers to separate quantities from ingredients
NUMBERS = ['seventeen', 'eighteen', 'thirteen', 'nineteen', 'fourteen', 'sixteen', 'fifteen', 'seventy', 'twelve',
           'eleven', 'eighty', 'thirty', 'ninety', 'twenty', 'seven', 'fifty', 'sixty', 'forty', 'three', 'eight',
           'four', 'zero', 'five', 'nine', 'ten', 'one', 'six', 'two', 'an', 'a', '½', '⅓','¼', '⅛', '¾']

prepositions = ["of"]

a = list(chain.from_iterable(UNITS.values()))
a.sort(key=lambda x: len(x), reverse=True)
a = map(escape_re_string, a)

PARSER_RE = re.compile(
    r'(?P<quantity>(?:[\d\.,][\d\.,\s/]*)?\s*(?:(?:%s)\s*)*)?(\s*(?P<unit>%s)\s+)?(\s*(?:%s)\s+)?(\s*(?P<name>.+))?' % (
        '|'.join(NUMBERS), '|'.join(a), '|'.join(prepositions)))


def parse(st):
    """

    :param st:
    :return:
    """
    st = normalize(st)
    res = PARSER_RE.match(st)
    
    return ((res.group('name') or '').strip())

# uncomment below code to return a tuple with measurement and ingredients

#     return ((res.group('quantity') or '').strip() + ' ' + (res.group('unit') or '').strip(),
#            (res.group('name') or '').strip())


# uncomment below code to return a dictionary with with measurements and ingredients as keys

#     return {
#             'measure': (res.group('quantity') or '').strip() + ' ' + (res.group('unit') or '').strip(),
#             'name': (res.group('name') or '').strip()
#         }

# %% [markdown]
# ### Scrape Recipes from AllRecipes with Recipe_Scrapers

# %%
# Time the seconds required to complete site scraping and filtering
start_time = time.time()

# Create an empty list for the scraped links
linklist=[]
for i in tqdm(range(1,994)):
    responses=requests.get('https://www.allrecipes.com/recipes/80/main-dish/?page={}'.format(i))
    soup=BeautifulSoup(responses.content,'html.parser')
    for link in soup.findAll('a', attrs={'href': re.compile("^https://")}):
        linklist.append(link.get('href'))

# Filter through links that correspond with a singular dish and not multiple dishes       
dishes = [k for k in linklist if '/recipe/' in k]

# Remove duplicate links
recipes = [] 
for d in dishes: 
    if d not in recipes: 
        recipes.append(d)

# Print time surpassed
print('-------- %s seconds --------' % (time.time() - start_time))
# Out:
# HBox(children=(IntProgress(value=0, max=993), HTML(value='')))
# -------- 963.9331917762756 seconds --------

# %%
# Count the number of recipes present after filtering
len(recipes)
# Out:
# 16379

# %%
start_time = time.time()

# Use Scrape_Me package on links
data = []

# Instantiate a progress bar within for loop 
for links in tqdm(recipes):
    data.append(scrape_me(links))
    

# Create lists for name, ingredients, and total time of recipes
names = []
ings = []
times = []
for dat in tqdm(data):
    try:
        names.append(dat.title())
        ings.append(dat.ingredients())
        times.append(dat.total_time())
    except Exception as ex:
        print(str(ex))
        

# Print time surpassed
print('-------- %s seconds --------' % (time.time() - start_time))
# Out:
# HBox(children=(IntProgress(value=0, max=16379), HTML(value='')))

# %%
# Check that all of the recipes were scraped
len(data)
# Out:
# 5667

# %% [markdown]
# ### Parse Ingredients of Each Recipe

# %%
new_list = []
for sub_list in ings:
    new_list.append([])
    for item in sub_list:
            new_list[-1].append(parse(item))
ings = new_list

# %% [markdown]
# ### Create and Save the DataFrame with Cleaned Data

# %%
# Create a dictionary to make a DataFrame from
alls = {'name':names, 'ingredients':ings1, 'total time (min)': times}
df = pd.DataFrame(alls)

# Preview DataFrame
df.head()
# Out:
# HBox(children=(IntProgress(value=0, max=5667), HTML(value='')))
#                                       name  \
# 0  World's Best Lasagna
# 1  Pork Chops in Garlic Mushroom Sauce
# 2  Super Duper Slow Cooker Beef Stroganoff
# 3  Chef John's Perfect Prime Rib
# 4  Beef Stroganoff for Instant Pot®
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ingredients
# 0  [1 pound sweet Italian sausage, 3/4 pound lean ground beef, 1/2 cup minced onion, 2 cloves garlic, crushed, 1 (28 ounce) can crushed tomatoes, 2 (6 ounce) cans tomato paste, 2 (6.5 ounce) cans canned tomato sauce, 1/2 cup water, 2 tablespoons white sugar, 1 1/2 teaspoons dried basil leaves, 1/2 teaspoon fennel seeds, 1 teaspoon Italian seasoning, 1 1/2 teaspoons salt, divided, or to taste, 1/4 teaspoon ground black pepper, 4 tablespoons chopped fresh parsley, 12 lasagna noodles, 16 ounces ricotta cheese, 1 egg, 3/4 pound mozzarella cheese, sliced, 3/4 cup grated Parmesan cheese]
# 1  [2 pounds boneless pork chops, 1/2 teaspoon paprika, 1 pinch kosher salt and ground black pepper to taste, 1/4 cup butter, divided, 1 (8 ounce) package sliced fresh mushrooms, 4 cloves garlic, minced, 1 teaspoon Dijon mustard, 2 tablespoons all-purpose flour, 2 cups beef broth]
# 2  [1 1/2 pounds cubed beef stew meat, salt and ground black pepper to taste, 1 onion, chopped, 1 (10.75 ounce) can condensed cream of mushroom soup, 1/4 cup water, 1 tablespoon dried chives, 2 cloves garlic, minced, 1 tablespoon Worcestershire sauce, 1 cube beef bouillon, 1/2 cup red wine, 1 tablespoon cornstarch, 1 tablespoon all-purpose flour, 1 (8 ounce) container sour cream, 1 (8 ounce) package sliced fresh mushrooms, 4 ounces cream cheese, 1/2 cup chopped fresh parsley]
# 3  [4 pounds prime rib roast, 1/4 cup unsalted butter, softened, 1 tablespoon freshly ground black pepper, 1 teaspoon herbes de Provence, kosher salt]
# 4  [2 tablespoons canola oil, 1/2 onion, diced, 2 teaspoons salt, divided, 2 pounds beef stew meat, cut into 1-inch cubes, 1 teaspoon freshly ground black pepper, 3 cloves garlic, minced, 1/2 teaspoon dried thyme, 2 tablespoons soy sauce, 3 cups chopped mushrooms, 2 tablespoons all-purpose flour, 3 cups chicken broth, 1 (16 ounce) package wide egg noodles, 3/4 cup sour cream, or to taste]

# %%
# Save the DataFrame
df.to_csv(r'/Users/stephaniekendall/Desktop/Errthang/Flatiron/projects/FP_Practice/hopeful.csv')

# %%
# Scrape the ratings for the recipes

# Determine the best way to get rating data, 1 average score or multiple

# ratings = []

# for recipe in tqdm(recipes):
#     responses = requests.get(recipe)
#     soup = BeautifulSoup(responses.content, 'html.parser')
#     rating = soup.find('meta', property='og:rating')
#     rating1 = soup.find('span', {'class':'review-star-text'}) 
#     ratings.append(rating['content'] if rating else rating1.text)
# Out:
# HBox(children=(IntProgress(value=0, max=5667), HTML(value='')))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1347471ab85b> in <module>
#       2
#       3 for recipe in tqdm(recipes[:5667]):
# ----> 4     responses = requests.get(recipe)
#       5     soup = BeautifulSoup(responses.content, 'html.parser')
#       6     rating = soup.find('meta', property='og:rating')
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
df['ingredients'].apply(pd.Series)
# Out:
#                                                       0  \
# 0   5 teaspoons olive oil
# 1   1/2 pound ground turkey
# 2   1 1/2 cups uncooked white rice
# 3   3 pounds beef roast
# 4   1 egg
# 5   8 ounces farfalle (bow tie) pasta
# 6   1 tablespoon olive oil
# 7   1 ¼ pounds skinless, boneless chicken breast halves
# 8   10 ounces fettuccini pasta
# 9   1 tablespoon butter
# 10  Meatloaf Ingredients:
# 11  1/2 cup chopped red bell pepper
# 12  6 ounces spaghetti
# 13  ½ cup balsamic vinegar
# 14  2 cups water
# 15  1 1/2 cups mayonnaise
# 16  1 tablespoon canola oil
# 17  2 eggs
# 18  1/3 cup soy sauce
# 19  1/4 cup soy sauce
#
#                                                                       1  \
# 0   4 shallots, diced
# 1   1 egg
# 2   3 cups water
# 3   6 potatoes
# 4   1/4 cup milk
# 5   1/4 cup butter
# 6   1 (3 pound) roasting chicken, deboned and cut into bite size pieces
# 7   3 tablespoons all-purpose flour
# 8   1/2 cup butter
# 9   1/2 cup minced white onion
# 10  1 carrot, coarsely chopped
# 11  1/2 cup chopped zucchini
# 12  3 quarts water
# 13  1 tablespoon olive oil
# 14  1 cup uncooked white rice
# 15  1/2 cup prepared mustard
# 16  1 (2 pound) boneless pork loin roast, cut into 1-inch cubes
# 17  1 teaspoon lemon pepper
# 18  1/4 cup olive oil
# 19  1 tablespoon mirin (Japanese sweet wine)
#
#                                                2  \
# 0   1 large onion, cut into thin strips
# 1   1/4 cup salsa
# 2   4 tablespoons vegetable oil
# 3   1 1/2 cups baby carrots
# 4   1 pound ground beef
# 5   1 clove garlic, minced
# 6   2 cloves garlic, crushed
# 7   2 tablespoons olive oil
# 8   5 cloves garlic, chopped
# 9   3 cloves garlic, minced
# 10  1 rib celery, coarsely chopped
# 11  1/2 cup chopped yellow squash
# 12  1 teaspoon salt
# 13  1 tablespoon Dijon mustard, or more to taste
# 14  1 pound medium shrimp, peeled and deveined
# 15  1 teaspoon chopped fresh thyme
# 16  2 (14.5 ounce) cans enchilada sauce
# 17  1 teaspoon garlic pepper
# 18  1/4 cup brown sugar
# 19  1 tablespoon honey
#
#                                             3  \
# 0   1 pound bacon, cut into strips
# 1   1/8 cup chopped red bell pepper
# 2   1 cup fresh bean sprouts
# 3   1 yellow onion
# 4   1/4 cup dry cream of wheat cereal
# 5   1/4 cup all-purpose flour
# 6   1 onion, chopped
# 7   2 teaspoons butter
# 8   1 cup heavy cream
# 9   1 tablespoon chopped fresh thyme
# 10  1/2 onion, coarsely chopped
# 11  1/2 cup chopped red onion
# 12  1 tablespoon butter
# 13  1 clove garlic, or more to taste, minced
# 14  1/4 teaspoon ground ginger
# 15  1 teaspoon dried oregano
# 16  2 (15.5 ounce) cans white hominy, drained
# 17  1 cup ground almonds
# 18  2 teaspoons lemon pepper
# 19  2 tablespoons sesame oil
#
#                                           4  \
# 0   1 clove garlic, chopped
# 1   1/8 cup chopped yellow bell pepper
# 2   1/2 cup chopped onion
# 3   2 stalks celery
# 4   1/4 cup minced onion
# 5   1/2 teaspoon salt
# 6   1 large potato, diced
# 7   2 tablespoons shallots, minced
# 8   1 egg yolk
# 9   3/4 cup low-sodium beef broth
# 10  1/2 red bell pepper, coarsely chopped
# 11  1/2 cup chopped mushrooms
# 12  2 tablespoons chopped onion
# 13  salt and freshly ground pepper to taste
# 14  1/4 teaspoon cayenne pepper
# 15  1 teaspoon chopped fresh basil leaves
# 16  1 onion, sliced
# 17  1 cup freshly grated Parmesan cheese
# 18  2 cloves garlic, minced
# 19  1 tablespoon rice wine vinegar
#
#                                                                     5  \
# 0   1 (16 ounce) package fettuccini pasta
# 1   1/4 cup chopped onion
# 2   1 1/2 cups cooked medium shrimp, peeled and deveined without tail
# 3   3 cubes beef bouillon
# 4   1 (10.75 ounce) can condensed cream of chicken soup
# 5   1/8 teaspoon ground black pepper
# 6   1 teaspoon ground cumin
# 7   2 cloves garlic, minced
# 8   2 cups freshly grated Parmesan cheese
# 9   1/2 cup port wine
# 10  4 white mushrooms, coarsely chopped
# 11  1 tablespoon olive oil
# 12  1 (10.75 ounce) can condensed cream of mushroom soup
# 13  4 large skinless, boneless chicken breast halves
# 14  1 clove garlic, minced
# 15  1 1/2 pounds salmon fillets
# 16  1/2 cup green chilies, diced
# 17  8 (6 ounce) tilapia fillets
# 18  1 pound skin-on salmon fillet
# 19  4 (6 ounce) tuna steaks
#
#                                                        6  \
# 0   3 egg yolks
# 1   1/4 cup dry bread crumbs
# 2   1/4 cup chopped green onion
# 3   1/2 cup water
# 4   1 (10.75 ounce) can condensed cream of mushroom soup
# 5   2 cups milk
# 6   1 teaspoon ground coriander seed
# 7   1 cup water
# 8   2 tablespoons dried parsley
# 9   1 tablespoon vegetable oil
# 10  3 cloves garlic, coarsely chopped
# 11  cooking spray
# 12  1/2 cup water
# 13  1 pint cherry tomatoes, halved
# 14  1 tablespoon sesame seeds
# 15  2 teaspoons dried dill, or to taste
# 16  4 cloves garlic, minced
# 17  1/4 cup all-purpose flour for dusting
# 18  NaN
# 19  1/2 cup sesame seeds
#
#                                            7  \
# 0   1/2 cup heavy cream
# 1   lemon pepper to taste
# 2   2 eggs, beaten
# 3   NaN
# 4   1 (12 fluid ounce) can evaporated milk
# 5   1/2 teaspoon prepared mustard
# 6   1 teaspoon ground black pepper
# 7   ½ cup white wine
# 8   NaN
# 9   4 filet mignon steaks (1 1/2 inch thick)
# 10  2 1/2 pounds ground chuck
# 11  6 (9 inch) whole wheat tortillas
# 12  1/2 cup shredded Cheddar cheese
# 13  1 lemon, zested and juiced
# 14  1/4 teaspoon ground black pepper
# 15  NaN
# 16  1/2 teaspoon cayenne pepper, or to taste
# 17  6 tablespoons butter
# 18  NaN
# 19  wasabi paste
#
#                                                        8  \
# 0   3/4 cup shredded Parmesan cheese
# 1   NaN
# 2   1 teaspoon salt
# 3   NaN
# 4   1 tablespoon chopped fresh parsley
# 5   2 1/2 cups shredded Colby cheese
# 6   1 teaspoon crushed red pepper flakes
# 7   1 cube chicken bouillon
# 8   NaN
# 9   3/4 cup crumbled blue cheese
# 10  1 tablespoon Worcestershire sauce
# 11  1 1/4 cups shredded reduced-fat sharp Cheddar cheese
# 12  1 cup diced ham
# 13  NaN
# 14  2 tablespoons sesame oil
# 15  NaN
# 16  2 teaspoons dried oregano
# 17  salt to taste
# 18  NaN
# 19  1 tablespoon olive oil
#
#                                              9  \
# 0   salt and pepper to taste
# 1   NaN
# 2   1/4 teaspoon ground black pepper
# 3   NaN
# 4   NaN
# 5   4 ounces cooked ham, julienned
# 6   1 teaspoon salt
# 7   ½ teaspoon dried rosemary, crushed
# 8   NaN
# 9   1/4 cup panko bread crumbs
# 10  1 egg, beaten
# 11  NaN
# 12  2 tablespoons chopped fresh parsley
# 13  NaN
# 14  1 red bell pepper, sliced into thin strips
# 15  NaN
# 16  1/4 cup cilantro, chopped
# 17  1 cup freshly grated Parmesan cheese
# 18  NaN
# 19  NaN
#
#                                        10  \
# 0   NaN
# 1   NaN
# 2   4 tablespoons soy sauce
# 3   NaN
# 4   NaN
# 5   1/4 cup grated Parmesan cheese
# 6   1 cup water
# 7   ¼ teaspoon salt
# 8   NaN
# 9   NaN
# 10  1 teaspoon dried Italian herbs
# 11  NaN
# 12  2 tablespoons chopped pimento peppers
# 13  NaN
# 14  3 green onions, sliced
# 15  NaN
# 16  1/2 teaspoon salt
# 17  8 sprigs parsley
# 18  NaN
# 19  NaN
#
#                                             11  \
# 0   NaN
# 1   NaN
# 2   1/4 teaspoon sesame oil
# 3   NaN
# 4   NaN
# 5   NaN
# 6   ¾ cup unsalted natural-style peanut butter
# 7   1 pinch ground black pepper
# 8   NaN
# 9   NaN
# 10  2 teaspoons salt
# 11  NaN
# 12  NaN
# 13  NaN
# 14  3 tablespoons teriyaki sauce
# 15  NaN
# 16  NaN
# 17  8 lemon wedges
# 18  NaN
# 19  NaN
#
#                                                      12  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   1 (15 ounce) can garbanzo beans, drained and rinsed
# 7   NaN
# 8   NaN
# 9   NaN
# 10  1 teaspoon ground black pepper
# 11  NaN
# 12  NaN
# 13  NaN
# 14  1/2 pound sugar snap peas
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
#
#                              13                        14  \
# 0   NaN                          NaN
# 1   NaN                          NaN
# 2   NaN                          NaN
# 3   NaN                          NaN
# 4   NaN                          NaN
# 5   NaN                          NaN
# 6   NaN                          NaN
# 7   NaN                          NaN
# 8   NaN                          NaN
# 9   NaN                          NaN
# 10  1/2 teaspoon cayenne pepper  1 cup plain bread crumbs
# 11  NaN                          NaN
# 12  NaN                          NaN
# 13  NaN                          NaN
# 14  1/8 cup cornstarch           3/4 cup chicken broth
# 15  NaN                          NaN
# 16  NaN                          NaN
# 17  NaN                          NaN
# 18  NaN                          NaN
# 19  NaN                          NaN
#
#                       15                  16                         17  \
# 0   NaN                   NaN                 NaN
# 1   NaN                   NaN                 NaN
# 2   NaN                   NaN                 NaN
# 3   NaN                   NaN                 NaN
# 4   NaN                   NaN                 NaN
# 5   NaN                   NaN                 NaN
# 6   NaN                   NaN                 NaN
# 7   NaN                   NaN                 NaN
# 8   NaN                   NaN                 NaN
# 9   NaN                   NaN                 NaN
# 10  1 teaspoon olive oil  Glaze Ingredients:  2 tablespoons brown sugar
# 11  NaN                   NaN                 NaN
# 12  NaN                   NaN                 NaN
# 13  NaN                   NaN                 NaN
# 14  1/4 teaspoon salt     NaN                 NaN
# 15  NaN                   NaN                 NaN
# 16  NaN                   NaN                 NaN
# 17  NaN                   NaN                 NaN
# 18  NaN                   NaN                 NaN
# 19  NaN                   NaN                 NaN
#
#                        18                           19  \
# 0   NaN                    NaN
# 1   NaN                    NaN
# 2   NaN                    NaN
# 3   NaN                    NaN
# 4   NaN                    NaN
# 5   NaN                    NaN
# 6   NaN                    NaN
# 7   NaN                    NaN
# 8   NaN                    NaN
# 9   NaN                    NaN
# 10  2 tablespoons ketchup  2 tablespoons Dijon mustard
# 11  NaN                    NaN
# 12  NaN                    NaN
# 13  NaN                    NaN
# 14  NaN                    NaN
# 15  NaN                    NaN
# 16  NaN                    NaN
# 17  NaN                    NaN
# 18  NaN                    NaN
# 19  NaN                    NaN
#
#                            20
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  hot pepper sauce to taste
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
